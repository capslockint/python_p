# %%
'''What question(s) are you trying to solve (or prove wrong)?
What kind of data do you have and how do you treat different types?
What’s missing from the data and how do you deal with it?
Where are the outliers and why should you care about them?
How can you add, change or remove features to get more out of your data?'''

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HR_Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome    Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  \
# 0                 1     Bachelor  Life Sciences              1
# 1                 8  High School  Life Sciences              1
# 2                 2     Bachelor          Other              1
# 3                 3          PhD  Life Sciences              1
# 4                 2  High School        Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %%
df.head(15)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df.tail(15)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1455   40        No      Travel_Rarely       1322  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1457   40        No      Travel_Rarely       1194  Research & Development
# 1458   35        No      Travel_Rarely        287  Research & Development
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df_obj = df.select_dtypes(['object'])
df_obj
# Out:
#      Attrition     BusinessTravel              Department    Education  \
# 0          Yes      Travel_Rarely                   Sales     Bachelor
# 1           No  Travel_Frequently  Research & Development  High School
# 2          Yes      Travel_Rarely  Research & Development     Bachelor
# 3           No  Travel_Frequently  Research & Development          PhD
# 4           No      Travel_Rarely  Research & Development  High School
# ...        ...                ...                     ...          ...
# 1465        No  Travel_Frequently  Research & Development     Bachelor
# 1466        No      Travel_Rarely  Research & Development  High School
# 1467        No      Travel_Rarely  Research & Development       Master
# 1468        No  Travel_Frequently                   Sales       Master
# 1469        No      Travel_Rarely  Research & Development       Master
#
#      EducationField  Gender                    JobRole MaritalStatus Over18  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# bye default it remove white spaces 
#it also remove leading and trailing character
df.columns.str.strip()
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
s = pd.Series(['1. Bat. ','2. Dog!\n','3. Fox?\t'])
s
# Out:
# 0     1. Bat.
# 1    2. Dog!\n
# 2    3. Fox?\t
# dtype: object

# %%
# general description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
s.str.strip('123.!? \n\t')
# Out:
# 0    Bat
# 1    Dog
# 2    Fox
# dtype: object

# %%
s = pd.Series(['1. Bat cy','2. Dog cy','3. Fox cy'])
print(s)
s1 = s.str.replace("cy", "$")
print("after replace")
print(s1)
print("after strip")
s2 = s.str.strip('cy')
print(s2)
# Out:
# 0    1. Bat cy
# 1    2. Dog cy
# 2    3. Fox cy
# dtype: object
# after replace
# 0    1. Bat $
# 1    2. Dog $
# 2    3. Fox $
# dtype: object
# after strip
# 0    1. Bat
# 1    2. Dog
# 2    3. Fox
# dtype: object

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                   object
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
'''2 .What kind of data do you have and how do you treat different types?'''
# Out:
# '2 .What kind of data do you have and how do you treat different types?'

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                   object
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#it gives the statical overview of the dataset
df.describe()  #numerical
# Out:
#                Age    DailyRate  DistanceFromHome  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000         1470.0
# mean     36.923810   802.485714          9.192517            1.0
# std       9.135373   403.509100          8.106864            0.0
# min      18.000000   102.000000          1.000000            1.0
# 25%      30.000000   465.000000          2.000000            1.0
# 50%      36.000000   802.000000          7.000000            1.0
# 75%      43.000000  1157.000000         14.000000            1.0
# max      60.000000  1499.000000         29.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# ...

# %%
df.describe(include=['object'])
# Out:
#        Attrition BusinessTravel              Department Education  \
# count       1470           1470                    1470      1470
# unique         2              3                       3         5
# top           No  Travel_Rarely  Research & Development    Master
# freq        1233           1043                     961       572
#
#        EducationField Gender          JobRole MaritalStatus Over18 OverTime
# count            1470   1470             1470          1470   1470     1470
# unique              6      2                9             3      1        2
# top     Life Sciences   Male  Sales Executive       Married      Y       No
# freq              606    882              326           673   1470     1054

# %%
df.describe(include=['object', 'object'])
# Out:
#        Attrition BusinessTravel              Department Education  \
# count       1470           1470                    1470      1470
# unique         2              3                       3         5
# top           No  Travel_Rarely  Research & Development    Master
# freq        1233           1043                     961       572
#
#        EducationField Gender          JobRole MaritalStatus Over18 OverTime
# count            1470   1470             1470          1470   1470     1470
# unique              6      2                9             3      1        2
# top     Life Sciences   Male  Sales Executive       Married      Y       No
# freq              606    882              326           673   1470     1054

# %%
'''Topics Covered:
1. Uploading data in Jupyter notebook
2. Understanding data structure and features
3. Identifying datatypes
4. Describing data to view its statistics 
5. Removing extra characters
'''
# Out:
# 'Topics Covered:\n1. Uploading data in Jupyter notebook\n2. Understanding data structure and features\n3. Identifying datatypes\n4. Describing data to view its statistics \n5. Removing extra characters\n'

# %%
# EDA-S-3

# %%
'''
Topics Covered:
cut & qcut
str.strip() & str.replace()
loc & iloc
conditional statements
'''
# Out:
# '\nTopics Covered:\ncut & qcut\nstr.strip() & str.replace()\nloc & iloc\nconditional statements\n'

# %%
#to select a specfic data types
#select_dtypes(include=None, exclude=None)

df_obj = df.select_dtypes(['object'])
df_obj
# Out:
#      Attrition     BusinessTravel              Department    Education  \
# 0          Yes      Travel_Rarely                   Sales     Bachelor
# 1           No  Travel_Frequently  Research & Development  High School
# 2          Yes      Travel_Rarely  Research & Development     Bachelor
# 3           No  Travel_Frequently  Research & Development          PhD
# 4           No      Travel_Rarely  Research & Development  High School
# ...        ...                ...                     ...          ...
# 1465        No  Travel_Frequently  Research & Development     Bachelor
# 1466        No      Travel_Rarely  Research & Development  High School
# 1467        No      Travel_Rarely  Research & Development       Master
# 1468        No  Travel_Frequently                   Sales       Master
# 1469        No      Travel_Rarely  Research & Development       Master
#
#      EducationField  Gender                    JobRole MaritalStatus Over18  \
# ...

# %%
df_num = df.select_dtypes(['int64'])
df_num
# Out:
#       Age  DailyRate  DistanceFromHome  EmployeeCount  EmployeeNumber  \
# 0      41       1102                 1              1               1
# 1      49        279                 8              1               2
# 2      37       1373                 2              1               4
# 3      33       1392                 3              1               5
# 4      27        591                 2              1               7
# ...   ...        ...               ...            ...             ...
# 1465   36        884                23              1            2061
# 1466   39        613                 6              1            2062
# 1467   27        155                 4              1            2064
# 1468   49       1023                 2              1            2065
# 1469   34        628                 8              1            2068
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df['EducationField'].nunique()
# Out:
# 6

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
for column in df:
    print("Column"," ",column,"  uniquevalus  are :", df[column].nunique())
    print(df[column].unique())
    print("-------------------------")
# Out:
# Column   Age   uniquevalus  are : 43
# [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# -------------------------
# Column   Attrition   uniquevalus  are : 2
# ['Yes' 'No']
# -------------------------
# Column   BusinessTravel   uniquevalus  are : 3
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# -------------------------
# Column   DailyRate   uniquevalus  are : 886
# [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df['WorkLifeBalance'].value_counts()
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
for column in df:
    print("Column"," ",column," value counts is :", df[column].value_counts())
    print("-------------------------------------------------------")
# Out:
# Column   Age  value counts is : Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64
# -------------------------------------------------------
# Column   Attrition  value counts is : Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# -------------------------------------------------------
# Column   BusinessTravel  value counts is : BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# -------------------------------------------------------
# ...

# %%
#aggregrate statistics (groupby)

# %%
#conditional statement
df[df['Attrition']=='Yes']   # it will show how many rows are yes
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome    Education    EducationField  EmployeeCount  \
# ...

# %%
df[(df['Age']>=40) & (df['BusinessTravel'] == 'Travel_Rarely') & (df['DailyRate']>500)]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 0      41       Yes  Travel_Rarely       1102                   Sales
# 6      59        No  Travel_Rarely       1324  Research & Development
# 18     53        No  Travel_Rarely       1219                   Sales
# 25     53        No  Travel_Rarely       1282  Research & Development
# 27     42        No  Travel_Rarely        691                   Sales
# ...   ...       ...            ...        ...                     ...
# 1435   44        No  Travel_Rarely       1037  Research & Development
# 1445   41        No  Travel_Rarely        582  Research & Development
# 1448   41        No  Travel_Rarely        930                   Sales
# 1455   40        No  Travel_Rarely       1322  Research & Development
# 1457   40        No  Travel_Rarely       1194  Research & Development
#
#       DistanceFromHome Education EducationField  EmployeeCount  \
# ...

# %%
#duplicate handling     'data cleaning'

# %%
# it will show where my rows are repeting 'if yes it mean repeting'
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for column in df:
    duplicate_values = df[column].duplicated()
    print(duplicate_values)
    print("------------------------------------------")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# Name: Age, Length: 1470, dtype: bool
# ------------------------------------------
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# Name: Attrition, Length: 1470, dtype: bool
# ------------------------------------------
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# Name: BusinessTravel, Length: 1470, dtype: bool
# ------------------------------------------
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465     True
# 1466    False
# 1467     True
# 1468    False
# 1469    False
# ...

# %%
df.duplicated('EmployeeNumber').sum()
# Out:
# 0

# %%
df[df['EmployeeNumber'].duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
df[df['Age'].duplicated()==False]
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     41       Yes      Travel_Rarely       1102                   Sales
# 1     49        No  Travel_Frequently        279  Research & Development
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 3     33        No  Travel_Frequently       1392  Research & Development
# 4     27        No      Travel_Rarely        591  Research & Development
# 5     32        No  Travel_Frequently       1005  Research & Development
# 6     59        No      Travel_Rarely       1324  Research & Development
# 7     30        No      Travel_Rarely       1358  Research & Development
# 8     38        No  Travel_Frequently        216  Research & Development
# 9     36        No      Travel_Rarely       1299  Research & Development
# 10    35        No      Travel_Rarely        809  Research & Development
# 11    29        No      Travel_Rarely        153  Research & Development
# ...

# %%
colum_1 = df.columns
colum_1
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
colum_1.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
df1 = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum','Indomie', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup1', 'cup', 'pack', 'pack','pack'],
    'rating': [4, 4, 3.5, 15, 15, 15]
})
df1
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum  cup1     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack    15.0
# 5  Indomie  pack    15.0

# %%
df1.duplicated() #rows are complete duplicated
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
df1.duplicated().sum()
# Out:
# 2

# %%
t1 = df1.duplicated(keep='last')
t1
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
df1[df1.duplicated()==True]
# Out:
#      brand style  rating
# 4  Indomie  pack    15.0
# 5  Indomie  pack    15.0

# %%
t1 = df1.duplicated(keep='first')
t1
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
df['Age'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# Name: Age, Length: 1470, dtype: bool

# %%
#bye default it keep first
dft = df1.drop_duplicates(keep='last')
dft
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum  cup1     4.0
# 2  Indomie   cup     3.5
# 5  Indomie  pack    15.0

# %%
# qcut

# %%
df["Age"]
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
#breaking down accroding to qunatile
df["Agerange1"]=pd.qcut(df["Age"],q=4)
print(df['Agerange1'])
df
# Out:
# 0         (36.0, 43.0]
# 1         (43.0, 60.0]
# 2         (36.0, 43.0]
# 3         (30.0, 36.0]
# 4       (17.999, 30.0]
#              ...
# 1465      (30.0, 36.0]
# 1466      (36.0, 43.0]
# 1467    (17.999, 30.0]
# 1468      (43.0, 60.0]
# 1469      (30.0, 36.0]
# Name: Agerange1, Length: 1470, dtype: category
# Categories (4, interval[float64, right]): [(17.999, 30.0] < (30.0, 36.0] < (36.0, 43.0] < (43.0, 60.0]]
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# ...

# %%
#devide the colum in catagory
df[["Age","Agerange1"]]
# Out:
#       Age       Agerange1
# 0      41    (36.0, 43.0]
# 1      49    (43.0, 60.0]
# 2      37    (36.0, 43.0]
# 3      33    (30.0, 36.0]
# 4      27  (17.999, 30.0]
# ...   ...             ...
# 1465   36    (30.0, 36.0]
# 1466   39    (36.0, 43.0]
# 1467   27  (17.999, 30.0]
# 1468   49    (43.0, 60.0]
# 1469   34    (30.0, 36.0]
#
# [1470 rows x 2 columns]

# %%
# checking the count of catagory 
df["Agerange1"].value_counts()
# Out:
# Agerange1
# (30.0, 36.0]      412
# (17.999, 30.0]    386
# (43.0, 60.0]      347
# (36.0, 43.0]      325
# Name: count, dtype: int64

# %%
df["Agerange2"]=pd.qcut(df["Age"],q=10)
print(df['Agerange2'].value_counts())
df[["Age","Agerange2"]]
# Out:
# Agerange2
# (31.0, 34.0]      196
# (26.0, 29.0]      164
# (17.999, 26.0]    162
# (41.0, 45.0]      152
# (34.0, 36.0]      147
# (50.0, 60.0]      143
# (38.0, 41.0]      139
# (45.0, 50.0]      130
# (29.0, 31.0]      129
# (36.0, 38.0]      108
# Name: count, dtype: int64
#       Age     Agerange2
# 0      41  (38.0, 41.0]
# 1      49  (45.0, 50.0]
# 2      37  (36.0, 38.0]
# 3      33  (31.0, 34.0]
# 4      27  (26.0, 29.0]
# ...   ...           ...
# 1465   36  (34.0, 36.0]
# 1466   39  (38.0, 41.0]
# 1467   27  (26.0, 29.0]
# 1468   49  (45.0, 50.0]
# 1469   34  (31.0, 34.0]
#
# [1470 rows x 2 columns]

# %%
#labling our catagory
#set yourself

# %%
bin_lables_5 = ["young","mid young","middle","experience"]
df["age range 3"] = pd.qcut(df["Age"],q=4,labels=bin_lables_5)
df[["Age","Agerange1",'age range 3']]
# Out:
#       Age       Agerange1 age range 3
# 0      41    (36.0, 43.0]      middle
# 1      49    (43.0, 60.0]  experience
# 2      37    (36.0, 43.0]      middle
# 3      33    (30.0, 36.0]   mid young
# 4      27  (17.999, 30.0]       young
# ...   ...             ...         ...
# 1465   36    (30.0, 36.0]   mid young
# 1466   39    (36.0, 43.0]      middle
# 1467   27  (17.999, 30.0]       young
# 1468   49    (43.0, 60.0]  experience
# 1469   34    (30.0, 36.0]   mid young
#
# [1470 rows x 3 columns]
