# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.loc[0:10,['Age','Name']]
# Out:
#      Age                                               Name
# 0   22.0                            Braund, Mr. Owen Harris
# 1   38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   26.0                             Heikkinen, Miss. Laina
# 3   35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   35.0                           Allen, Mr. William Henry
# 5    NaN                                   Moran, Mr. James
# 6   54.0                            McCarthy, Mr. Timothy J
# 7    2.0                     Palsson, Master. Gosta Leonard
# 8   27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9   14.0                Nasser, Mrs. Nicholas (Adele Achem)
# 10   4.0                    Sandstrom, Miss. Marguerite Rut

# %%
#specific row
df.loc[[4,6,8],['Age','Name']]
# Out:
#     Age                                               Name
# 4  35.0                           Allen, Mr. William Henry
# 6  54.0                            McCarthy, Mr. Timothy J
# 8  27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)

# %%
df.loc[df['Age']<50].shape
# Out:
# (640, 12)

# %%
df.loc[df['Sex']=='female'].shape
# Out:
# (314, 12)

# %%
df.loc[df['Sex']=='male'].shape
# Out:
# (577, 12)

# %%
df.loc[(df['Sex']=='female') & (df['Fare']>31)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 25            26         1       3
# 31            32         1       1
# 43            44         1       2
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[(df['Sex']=='male') & (df['Fare']>31)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 13            14         0       3              Andersson, Mr. Anders Johan
# 23            24         1       1             Sloper, Mr. William Thompson
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 34            35         0       1                  Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                      ...
# 838          839         1       3                          Chip, Mr. Chang
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 848          849         0       2                        Harper, Rev. John
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 867          868         0       1     Roebling, Mr. Washington Augustus II
#
# ...

# %%
#ending index dont count
df.iloc[0:11,0:4]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 6                             McCarthy, Mr. Timothy J
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# ...

# %%
# last 3 colums and last 10 rows
df.iloc[-10:,-3:]
# Out:
#         Fare Cabin Embarked
# 881   7.8958   NaN        S
# 882  10.5167   NaN        S
# 883  10.5000   NaN        S
# 884   7.0500   NaN        S
# 885  29.1250   NaN        Q
# 886  13.0000   NaN        S
# 887  30.0000   B42        S
# 888  23.4500   NaN        S
# 889  30.0000  C148        C
# 890   7.7500   NaN        Q

# %%
# first 4 rows and 1 3 5 colum
df.iloc[[1,2,3,4],[1,3,5]]
# Out:
#    Survived                                               Name   Age
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1                             Heikkinen, Miss. Laina  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0                           Allen, Mr. William Henry  35.0

# %%
df['Age_bin']=pd.cut(df['Age'],bins=4)

# %%
bins=[0,18,35,60,100]
labels=['Child','Young Adult' , 'Adult', 'Senior']

# %%
df['Age_group']=pd.cut(df['Age'],bins=bins,labels=labels)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare_qnt']=pd.qcut(df['Fare'],q=4)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# age-group      177
# Age_bin        177
# fare_qnt         0
# Fare_qnt         0
# Age_group      177
# dtype: int64

# %%
#to drop missing value column
#df_drop_column = df.dropna(axis=1)
#df_drop_column

# %%
#deleting rows with missing values
#df_drop_rows = df.dropna(axis=0)
#df_drop_rows

# %%
missing_percentage = (df.isnull().sum()/len(df))*100
missing_percentage
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# age-group      19.865320
# Age_bin        19.865320
# fare_qnt        0.000000
# Fare_qnt        0.000000
# Age_group      19.865320
# dtype: float64

# %%
df_without_cabin = df.drop(columns=['Cabin'])
df_without_cabin
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
age_mean = df['Age'].mean()
age_mean
# Out:
# 29.69911764705882

# %%
#missing values ,, mean
df_without_cabin['Age'].fillna(age_mean,inplace=True)

# %%
df_without_cabin.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# age-group      177
# Age_bin        177
# fare_qnt         0
# Fare_qnt         0
# Age_group      177
# dtype: int64

# %%
emb_mode = df['Embarked'].mode()
emb_mode
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
emb_mode.[0]
# Out:
#   Cell In[80], line 1
#     emb_mode.[0]
#              ^
# SyntaxError: invalid syntax

# %%
df_without_cabin['Embarked'].fillna(emb_mode[0],inplace=True)

# %%
df_without_cabin.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# age-group      177
# Age_bin        177
# fare_qnt         0
# Fare_qnt         0
# Age_group      177
# dtype: int64
